# %%
from wxdata.fems.fems import get_single_station_data

# %%
df = get_single_station_data(45438, 30)

# %%
df
# Out:
#     stationName           observationTime NFDRType fuelModelType  \
# 0         ACTON  2025-08-13T02:00:00.000Z        O             Y
# 1         ACTON  2025-08-13T03:00:00.000Z        O             Y
# 2         ACTON  2025-08-13T04:00:00.000Z        O             Y
# 3         ACTON  2025-08-13T05:00:00.000Z        O             Y
# 4         ACTON  2025-08-13T06:00:00.000Z        O             Y
# ..          ...                       ...      ...           ...
# 696       ACTON  2025-09-11T22:00:00.000Z        O             Y
# 697       ACTON  2025-09-11T23:00:00.000Z        O             Y
# 698       ACTON  2025-09-12T00:00:00.000Z        O             Y
# 699       ACTON  2025-09-12T01:00:00.000Z        F             Y
# 700       ACTON  2025-09-12T01:00:00.000Z        O             Y
#
#      oneHR_TL_FuelMoisture  tenHR_TL_FuelMoisture  hundredHR_TL_FuelMoisture  \
# 0                     5.22                   5.81                       7.95
# ...

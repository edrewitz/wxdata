# %%
from wxdata.gfs.gefs import gefs_0p50_secondary_parameters
import numpy as np

# %%
ds = gefs_0p50_secondary_parameters('mean', western_bound=-120, eastern_bound=-60, northern_bound=50, southern_bound=20, final_forecast_hour=48)
# Out:
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/gens/prod/gefs.20250907/00/atmos/pgrb2bp5/
# Data in f:GEFS0P50 SECONDARY PARAMETERS/CONTROL/3 is current. Skipping download.

# %%
ds
# Out:
# <xarray.Dataset> Size: 109MB
# Dimensions:                          (step: 17, latitude: 61, longitude: 121,
#                                       isobaricInhPa: 20)
# Coordinates:
#   * step                             (step) float64 136B 0.0 3.0 ... 45.0 48.0
#   * latitude                         (latitude) float64 488B 50.0 49.5 ... 20.0
#   * longitude                        (longitude) float64 968B -120.0 ... -60.0
#   * isobaricInhPa                    (isobaricInhPa) float64 160B 975.0 ... 1.0
#     number                           int64 8B ...
#     time                             datetime64[ns] 8B ...
#     surface                          float64 8B ...
#     valid_time                       datetime64[ns] 8B ...
#     meanSea                          float64 8B ...
#     planetaryBoundaryLayer           float64 8B ...
# Data variables: (12/47)
# ...

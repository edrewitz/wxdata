# %%
from wxdata.gfs.gefs import gefs_0p50_secondary_parameters
import numpy as np

# %%
ds = gefs_0p50_secondary_parameters('members', western_bound=-120, eastern_bound=-60, northern_bound=50, southern_bound=20, final_forecast_hour=48, members=[1,2])
# Out:
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/gens/prod/gefs.20250907/18/atmos/pgrb2bp5/
# Data in f:GEFS0P50 SECONDARY PARAMETERS/MEMBERS is current. Skipping download.

# %%
ds
# Out:
# <xarray.Dataset> Size: 397MB
# Dimensions:                                                     (number: 2,
#                                                                  step: 17,
#                                                                  latitude: 61,
#                                                                  longitude: 121,
#                                                                  isobaricInhPa: 20,
#                                                                  depthBelowLandLayer: 4,
#                                                                  theta: 6,
#                                                                  potentialVorticity: 8,
#                                                                  pressureFromGroundLayer: 6)
# Coordinates: (12/24)
#   * number                                                      (number) int64 16B ...
#   * step                                                        (step) float64 136B ...
# ...

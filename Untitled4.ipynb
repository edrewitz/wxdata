# %%
from wxdata.gfs.gefs import gefs_0p50
import numpy as np

# %%
ds = gefs_0p50('members', western_bound=-120, eastern_bound=-60, northern_bound=50, southern_bound=20, final_forecast_hour=120, members=[1, 2])
# Out:
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/gens/prod/gefs.20250906/12/atmos/pgrb2ap5/
# ...

# %%
ds
# Out:
# <xarray.Dataset> Size: 196MB
# Dimensions:                                    (number: 2, step: 41,
#                                                 latitude: 61, longitude: 121,
#                                                 isobaricInhPa: 11)
# Coordinates: (12/13)
#   * number                                     (number) int64 16B 1 2
#   * step                                       (step) float64 328B 0.0 ... 120.0
#   * latitude                                   (latitude) float64 488B 50.0 ....
#   * longitude                                  (longitude) float64 968B -120....
#   * isobaricInhPa                              (isobaricInhPa) float64 88B 1e...
#     time                                       datetime64[ns] 8B 2025-09-06T1...
#     ...                                         ...
#     valid_time                                 datetime64[ns] 8B 2025-09-06T1...
#     meanSea                                    float64 8B 0.0
# ...

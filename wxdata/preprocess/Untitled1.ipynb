# %%
import xarray as xr
import glob
import sys
import logging
import numpy as np
import warnings
warnings.filterwarnings('ignore')

from keys import get_var_keys
from paths import get_branch_path
from conventions import standardize_var_keys
from coords import shift_longitude

sys.tracebacklimit = 0
logging.disable()

# %%
paths = get_branch_path('GEFS0P50', 'members', 3)

# %%
western_bound = -120
eastern_bound = -65
northern_bound = 50
southern_bound = 20
model = 'GEFS0P50'
cat = 'members'

# %%
paths = get_branch_path(model, cat, 3)

keys, short_names = get_var_keys(model)
ds_list_1 = []
for path in paths:

    file_pattern = f"{path}/*.grib2"
    ds1 = xr.open_mfdataset(file_pattern, concat_dim='step', combine='nested', coords='minimal', engine='cfgrib', compat='override', decode_timedelta=False, filter_by_keys={'typeOfLevel': 'surface'})
    ds1 = shift_longitude(ds1)
    ds1 = ds1.sel(longitude=slice(western_bound, eastern_bound, 1), latitude=slice(northern_bound, southern_bound, 1))
    ds_list_1.append(ds1)

ds_list_2 = []
for path in paths:
    file_pattern = f"{path}/*.grib2"
    ds2 = xr.open_mfdataset(file_pattern, concat_dim='step', combine='nested', coords='minimal', engine='cfgrib', compat='override', decode_timedelta=False, filter_by_keys={'typeOfLevel': 'meanSea'})
    ds2 = shift_longitude(ds2)
    ds2 = ds2.sel(longitude=slice(western_bound, eastern_bound, 1), latitude=slice(northern_bound, southern_bound, 1))
    ds_list_2.append(ds2)

ds_list_3 = []
for path in paths:
    file_pattern = f"{path}/*.grib2"
    ds3 = xr.open_mfdataset(file_pattern, concat_dim='step', combine='nested', coords='minimal', engine='cfgrib', compat='override', decode_timedelta=False, filter_by_keys={'typeOfLevel': 'depthBelowLandLayer'})
    ds3 = shift_longitude(ds3)
    ds3 = ds3.sel(longitude=slice(western_bound, eastern_bound, 1), latitude=slice(northern_bound, southern_bound, 1))
    ds_list_3.append(ds3)

ds_list_4 = []
for path in paths:
    file_pattern = f"{path}/*.grib2"
    ds4 = xr.open_mfdataset(file_pattern, concat_dim='step', combine='nested', coords='minimal', engine='cfgrib', compat='override', decode_timedelta=False, filter_by_keys={'typeOfLevel': 'heightAboveGround'})
    ds4 = shift_longitude(ds4)
    ds4 = ds4.sel(longitude=slice(western_bound, eastern_bound, 1), latitude=slice(northern_bound, southern_bound, 1))
    ds_list_4.append(ds4)

ds_list_5 = []
for path in paths:
    file_pattern = f"{path}/*.grib2"
    ds5 = xr.open_mfdataset(file_pattern, concat_dim='step', combine='nested', coords='minimal', engine='cfgrib', compat='override', decode_timedelta=False, filter_by_keys={'typeOfLevel': 'atmosphereSingleLayer'})
    ds5 = shift_longitude(ds5)
    ds5 = ds5.sel(longitude=slice(western_bound, eastern_bound, 1), latitude=slice(northern_bound, southern_bound, 1))
    ds_list_5.append(ds5)

ds_list_6 = []
for path in paths:
    file_pattern = f"{path}/*.grib2"
    ds6 = xr.open_mfdataset(file_pattern, concat_dim='step', combine='nested', coords='minimal', engine='cfgrib', compat='override', decode_timedelta=False, filter_by_keys={'typeOfLevel': 'pressureFromGroundLayer'})
    ds6 = shift_longitude(ds6)
    ds6 = ds6.sel(longitude=slice(western_bound, eastern_bound, 1), latitude=slice(northern_bound, southern_bound, 1))
    ds_list_6.append(ds6)

ds_list_7 = []
for path in paths:
    file_pattern = f"{path}/*.grib2"
    ds7 = xr.open_mfdataset(file_pattern, concat_dim='step', combine='nested', coords='minimal', engine='cfgrib', compat='override', decode_timedelta=False, filter_by_keys={'typeOfLevel': 'isobaricInhPa'})
    ds7 = shift_longitude(ds7)
    ds7 = ds7.sel(longitude=slice(western_bound, eastern_bound, 1), latitude=slice(northern_bound, southern_bound, 1))
    ds_list_7.append(ds7)

ds_list_8 = []
for path in paths:
    file_pattern = f"{path}/*.grib2"
    ds8 = xr.open_mfdataset(file_pattern, concat_dim='step', combine='nested', coords='minimal', engine='cfgrib', compat='override', decode_timedelta=False, filter_by_keys={'typeOfLevel': 'isobaricInhPa', 'shortName':'t'})
    ds8 = shift_longitude(ds8)
    ds8 = ds8.sel(longitude=slice(western_bound, eastern_bound, 1), latitude=slice(northern_bound, southern_bound, 1))
    ds_list_8.append(ds8)

ds_list_9 = []
for path in paths:
    file_pattern = f"{path}/*.grib2"
    ds9 = xr.open_mfdataset(file_pattern, concat_dim='step', combine='nested', coords='minimal', engine='cfgrib', compat='override', decode_timedelta=False, filter_by_keys={'typeOfLevel': 'isobaricInhPa', 'shortName':'r'})
    ds9 = shift_longitude(ds9)
    ds9 = ds9.sel(longitude=slice(western_bound, eastern_bound, 1), latitude=slice(northern_bound, southern_bound, 1))
    ds_list_9.append(ds9)

ds_list_10 = []
for path in paths:
    file_pattern = f"{path}/*.grib2"
    ds10 = xr.open_mfdataset(file_pattern, concat_dim='step', combine='nested', coords='minimal', engine='cfgrib', compat='override', decode_timedelta=False, filter_by_keys={'typeOfLevel': 'isobaricInhPa', 'shortName':'u'})
    ds10 = shift_longitude(ds10)
    ds10 = ds10.sel(longitude=slice(western_bound, eastern_bound, 1), latitude=slice(northern_bound, southern_bound, 1))
    ds_list_10.append(ds10)

ds_list_11 = []
for path in paths:
    file_pattern = f"{path}/*.grib2"
    ds11 = xr.open_mfdataset(file_pattern, concat_dim='step', combine='nested', coords='minimal', engine='cfgrib', compat='override', decode_timedelta=False, filter_by_keys={'typeOfLevel': 'isobaricInhPa', 'shortName':'v'})
    ds11 = shift_longitude(ds11)
    ds11 = ds11.sel(longitude=slice(western_bound, eastern_bound, 1), latitude=slice(northern_bound, southern_bound, 1))
    ds_list_11.append(ds11)

# %%
ds_list = []
ds_list.append(ds_list_1)
ds_list.append(ds_list_2)
ds_list.append(ds_list_3)
ds_list.append(ds_list_4)
ds_list.append(ds_list_5)
ds_list.append(ds_list_6)
ds_list.append(ds_list_7)
ds_list.append(ds_list_8)
ds_list.append(ds_list_9)
ds_list.append(ds_list_10)
ds_list.append(ds_list_11)

# %%
ds = xr.concat(ds_list_1, dim='number')
ds1 = xr.concat(ds_list_2, dim='number')
ds2 = xr.concat(ds_list_3, dim='number')
ds3 = xr.concat(ds_list_4, dim='number')
ds4 = xr.concat(ds_list_5, dim='number')
ds5 = xr.concat(ds_list_6, dim='number')
ds6 = xr.concat(ds_list_7, dim='number')
ds7 = xr.concat(ds_list_8, dim='number')
ds8 = xr.concat(ds_list_9, dim='number')
ds9 = xr.concat(ds_list_10, dim='number')
ds10 = xr.concat(ds_list_11, dim='number')

# %%
ds
# Out:
# <xarray.Dataset> Size: 137MB
# Dimensions:     (number: 3, step: 105, latitude: 61, longitude: 111)
# Coordinates:
#   * number      (number) int64 24B 1 2 3
#     time        datetime64[ns] 8B 2025-09-04T12:00:00
#   * step        (step) float64 840B 0.0 3.0 6.0 9.0 ... 366.0 372.0 378.0 384.0
#     surface     float64 8B 0.0
#   * latitude    (latitude) float64 488B 50.0 49.5 49.0 48.5 ... 21.0 20.5 20.0
#     valid_time  datetime64[ns] 8B 2025-09-04T12:00:00
#   * longitude   (longitude) float64 888B -120.0 -119.5 -119.0 ... -65.5 -65.0
# Data variables: (12/16)
#     sp          (number, step, latitude, longitude) float32 9MB dask.array<chunksize=(1, 1, 61, 111), meta=np.ndarray>
#     orog        (number, step, latitude, longitude) float32 9MB dask.array<chunksize=(1, 1, 61, 111), meta=np.ndarray>
#     sdwe        (number, step, latitude, longitude) float32 9MB dask.array<chunksize=(1, 1, 61, 111), meta=np.ndarray>
#     sde         (number, step, latitude, longitude) float32 9MB dask.array<chunksize=(1, 1, 61, 111), meta=np.ndarray>
#     sithick     (number, step, latitude, longitude) float32 9MB dask.array<chunksize=(1, 1, 61, 111), meta=np.ndarray>
#     tp          (number, step, latitude, longitude) float32 9MB dask.array<chunksize=(1, 1, 61, 111), meta=np.ndarray>
#     ...          ...
#     avg_slhtf   (number, step, latitude, longitude) float32 9MB dask.array<chunksize=(1, 1, 61, 111), meta=np.ndarray>
#     avg_ishf    (number, step, latitude, longitude) float32 9MB dask.array<chunksize=(1, 1, 61, 111), meta=np.ndarray>
#     sdswrf      (number, step, latitude, longitude) float32 9MB dask.array<chunksize=(1, 1, 61, 111), meta=np.ndarray>
#     sdlwrf      (number, step, latitude, longitude) float32 9MB dask.array<chunksize=(1, 1, 61, 111), meta=np.ndarray>
#     suswrf      (number, step, latitude, longitude) float32 9MB dask.array<chunksize=(1, 1, 61, 111), meta=np.ndarray>
#     sulwrf      (number, step, latitude, longitude) float32 9MB dask.array<chunksize=(1, 1, 61, 111), meta=np.ndarray>
# Attributes:
#     GRIB_edition:            2
#     GRIB_centre:             kwbc
#     GRIB_centreDescription:  US National Weather Service - NCEP
#     GRIB_subCentre:          2
#     Conventions:             CF-1.7
#     institution:             US National Weather Service - NCEP
#     history:                 2025-09-05T17:33 GRIB to CDM+CF via cfgrib-0.9.1...

# %%
ds1
# Out:
# <xarray.Dataset> Size: 9MB
# Dimensions:     (number: 3, step: 105, latitude: 61, longitude: 111)
# Coordinates:
#   * number      (number) int64 24B 1 2 3
#     time        datetime64[ns] 8B 2025-09-04T12:00:00
#   * step        (step) float64 840B 0.0 3.0 6.0 9.0 ... 366.0 372.0 378.0 384.0
#     meanSea     float64 8B 0.0
#   * latitude    (latitude) float64 488B 50.0 49.5 49.0 48.5 ... 21.0 20.5 20.0
#     valid_time  datetime64[ns] 8B 2025-09-04T12:00:00
#   * longitude   (longitude) float64 888B -120.0 -119.5 -119.0 ... -65.5 -65.0
# Data variables:
#     prmsl       (number, step, latitude, longitude) float32 9MB dask.array<chunksize=(1, 1, 61, 111), meta=np.ndarray>
# Attributes:
#     GRIB_edition:            2
#     GRIB_centre:             kwbc
#     GRIB_centreDescription:  US National Weather Service - NCEP
#     GRIB_subCentre:          2
#     Conventions:             CF-1.7
#     institution:             US National Weather Service - NCEP
#     history:                 2025-09-05T17:35 GRIB to CDM+CF via cfgrib-0.9.1...

# %%
ds['prmsl'] = ds1['prmsl'][:, :, :, :]

# %%
ds['st'] = ds2['st'][:, :, :,:]
ds['soilw'] = ds2['soilw'][:, :, :,:]

# %%
ds3
# Out:
# <xarray.Dataset> Size: 34MB
# Dimensions:            (number: 3, step: 105, latitude: 61, longitude: 111)
# Coordinates:
#   * number             (number) int64 24B 1 2 3
#     time               datetime64[ns] 8B 2025-09-04T12:00:00
#   * step               (step) float64 840B 0.0 3.0 6.0 9.0 ... 372.0 378.0 384.0
#     heightAboveGround  float64 8B 2.0
#   * latitude           (latitude) float64 488B 50.0 49.5 49.0 ... 21.0 20.5 20.0
#     valid_time         datetime64[ns] 8B 2025-09-04T12:00:00
#   * longitude          (longitude) float64 888B -120.0 -119.5 ... -65.5 -65.0
# Data variables:
#     t2m                (number, step, latitude, longitude) float32 9MB dask.array<chunksize=(1, 1, 61, 111), meta=np.ndarray>
#     r2                 (number, step, latitude, longitude) float32 9MB dask.array<chunksize=(1, 1, 61, 111), meta=np.ndarray>
#     tmax               (number, step, latitude, longitude) float32 9MB dask.array<chunksize=(1, 1, 61, 111), meta=np.ndarray>
#     tmin               (number, step, latitude, longitude) float32 9MB dask.array<chunksize=(1, 1, 61, 111), meta=np.ndarray>
# Attributes:
#     GRIB_edition:            2
#     GRIB_centre:             kwbc
#     GRIB_centreDescription:  US National Weather Service - NCEP
#     GRIB_subCentre:          2
#     Conventions:             CF-1.7
#     institution:             US National Weather Service - NCEP
#     history:                 2025-09-05T17:35 GRIB to CDM+CF via cfgrib-0.9.1...

# %%
ds['t2m'] = ds3['t2m'][:, :, :,:]
ds['r2'] = ds3['r2'][:, :, :,:]
ds['tmax'] = ds3['tmax'][:, :, :,:]
ds['tmin'] = ds3['tmin'][:, :, :,:]

# %%
ds4
# Out:
# <xarray.Dataset> Size: 9MB
# Dimensions:                (number: 3, step: 105, latitude: 61, longitude: 111)
# Coordinates:
#   * number                 (number) int64 24B 1 2 3
#     time                   datetime64[ns] 8B 2025-09-04T12:00:00
#   * step                   (step) float64 840B 0.0 3.0 6.0 ... 372.0 378.0 384.0
#     atmosphereSingleLayer  float64 8B 0.0
#   * latitude               (latitude) float64 488B 50.0 49.5 49.0 ... 20.5 20.0
#     valid_time             datetime64[ns] 8B 2025-09-04T12:00:00
#   * longitude              (longitude) float64 888B -120.0 -119.5 ... -65.0
# Data variables:
#     pwat                   (number, step, latitude, longitude) float32 9MB dask.array<chunksize=(1, 1, 61, 111), meta=np.ndarray>
# Attributes:
#     GRIB_edition:            2
#     GRIB_centre:             kwbc
#     GRIB_centreDescription:  US National Weather Service - NCEP
#     GRIB_subCentre:          2
#     Conventions:             CF-1.7
#     institution:             US National Weather Service - NCEP
#     history:                 2025-09-05T17:36 GRIB to CDM+CF via cfgrib-0.9.1...

# %%
ds['pwat'] = ds4['pwat'][:, :, :,:]

# %%
ds5
# Out:
# <xarray.Dataset> Size: 17MB
# Dimensions:                  (number: 3, step: 105, latitude: 61, longitude: 111)
# Coordinates:
#   * number                   (number) int64 24B 1 2 3
#     time                     datetime64[ns] 8B 2025-09-04T12:00:00
#   * step                     (step) float64 840B 0.0 3.0 6.0 ... 378.0 384.0
#     pressureFromGroundLayer  float64 8B 1.8e+04
#   * latitude                 (latitude) float64 488B 50.0 49.5 ... 20.5 20.0
#     valid_time               datetime64[ns] 8B 2025-09-04T12:00:00
#   * longitude                (longitude) float64 888B -120.0 -119.5 ... -65.0
# Data variables:
#     cape                     (number, step, latitude, longitude) float32 9MB dask.array<chunksize=(1, 1, 61, 111), meta=np.ndarray>
#     cin                      (number, step, latitude, longitude) float32 9MB dask.array<chunksize=(1, 1, 61, 111), meta=np.ndarray>
# Attributes:
#     GRIB_edition:            2
#     GRIB_centre:             kwbc
#     GRIB_centreDescription:  US National Weather Service - NCEP
#     GRIB_subCentre:          2
#     Conventions:             CF-1.7
#     institution:             US National Weather Service - NCEP
#     history:                 2025-09-05T17:36 GRIB to CDM+CF via cfgrib-0.9.1...

# %%
ds['cape'] = ds5['cape'][:, :, :,:]
ds['cin'] = ds5['cin'][:, :, :,:]

# %%
ds6
# Out:
# <xarray.Dataset> Size: 94MB
# Dimensions:        (number: 3, step: 105, isobaricInhPa: 11, latitude: 61,
#                     longitude: 111)
# Coordinates:
#   * number         (number) int64 24B 1 2 3
#     time           datetime64[ns] 8B 2025-09-04T12:00:00
#   * step           (step) float64 840B 0.0 3.0 6.0 9.0 ... 372.0 378.0 384.0
#   * isobaricInhPa  (isobaricInhPa) float64 88B 1e+03 925.0 850.0 ... 50.0 10.0
#   * latitude       (latitude) float64 488B 50.0 49.5 49.0 ... 21.0 20.5 20.0
#     valid_time     datetime64[ns] 8B 2025-09-04T12:00:00
#   * longitude      (longitude) float64 888B -120.0 -119.5 -119.0 ... -65.5 -65.0
# Data variables:
#     gh             (number, step, isobaricInhPa, latitude, longitude) float32 94MB dask.array<chunksize=(1, 1, 11, 61, 111), meta=np.ndarray>
# Attributes:
#     GRIB_edition:            2
#     GRIB_centre:             kwbc
#     GRIB_centreDescription:  US National Weather Service - NCEP
#     GRIB_subCentre:          2
#     Conventions:             CF-1.7
#     institution:             US National Weather Service - NCEP
#     history:                 2025-09-05T17:36 GRIB to CDM+CF via cfgrib-0.9.1...

# %%
ds['gh'] = ds6['gh'][:, :, :, :,:]
ds['t'] = ds7['t'][:, :, :, :,:]
ds['r'] = ds8['r'][:, :, :, :,:]
ds['u'] = ds9['u'][:, :, :, :,:]
ds['v'] = ds10['v'][:, :, :, :,:]

# %%
ds
# Out:
# <xarray.Dataset> Size: 691MB
# Dimensions:                  (number: 3, step: 105, latitude: 61,
#                               longitude: 111, isobaricInhPa: 11)
# Coordinates: (12/13)
#   * number                   (number) int64 24B 1 2 3
#   * step                     (step) float64 840B 0.0 3.0 6.0 ... 378.0 384.0
#   * latitude                 (latitude) float64 488B 50.0 49.5 ... 20.5 20.0
#   * longitude                (longitude) float64 888B -120.0 -119.5 ... -65.0
#   * isobaricInhPa            (isobaricInhPa) float64 88B 1e+03 925.0 ... 10.0
#     time                     datetime64[ns] 8B 2025-09-04T12:00:00
#     ...                       ...
#     valid_time               datetime64[ns] 8B 2025-09-04T12:00:00
#     meanSea                  float64 8B 0.0
#     depthBelowLandLayer      float64 8B 0.0
#     heightAboveGround        float64 8B 2.0
#     atmosphereSingleLayer    float64 8B 0.0
#     pressureFromGroundLayer  float64 8B 1.8e+04
# Data variables: (12/31)
#     sp                       (number, step, latitude, longitude) float32 9MB dask.array<chunksize=(1, 1, 61, 111), meta=np.ndarray>
#     orog                     (number, step, latitude, longitude) float32 9MB dask.array<chunksize=(1, 1, 61, 111), meta=np.ndarray>
#     sdwe                     (number, step, latitude, longitude) float32 9MB dask.array<chunksize=(1, 1, 61, 111), meta=np.ndarray>
#     sde                      (number, step, latitude, longitude) float32 9MB dask.array<chunksize=(1, 1, 61, 111), meta=np.ndarray>
#     sithick                  (number, step, latitude, longitude) float32 9MB dask.array<chunksize=(1, 1, 61, 111), meta=np.ndarray>
#     tp                       (number, step, latitude, longitude) float32 9MB dask.array<chunksize=(1, 1, 61, 111), meta=np.ndarray>
#     ...                       ...
#     cin                      (number, step, latitude, longitude) float32 9MB dask.array<chunksize=(1, 1, 61, 111), meta=np.ndarray>
#     gh                       (number, step, isobaricInhPa, latitude, longitude) float32 94MB dask.array<chunksize=(1, 1, 11, 61, 111), meta=np.ndarray>
#     t                        (number, step, isobaricInhPa, latitude, longitude) float32 94MB dask.array<chunksize=(1, 1, 10, 61, 111), meta=np.ndarray>
#     r                        (number, step, isobaricInhPa, latitude, longitude) float32 94MB dask.array<chunksize=(1, 1, 10, 61, 111), meta=np.ndarray>
#     u                        (number, step, isobaricInhPa, latitude, longitude) float32 94MB dask.array<chunksize=(1, 1, 11, 61, 111), meta=np.ndarray>
#     v                        (number, step, isobaricInhPa, latitude, longitude) float32 94MB dask.array<chunksize=(1, 1, 11, 61, 111), meta=np.ndarray>
# Attributes:
#     GRIB_edition:            2
#     GRIB_centre:             kwbc
#     GRIB_centreDescription:  US National Weather Service - NCEP
#     GRIB_subCentre:          2
#     Conventions:             CF-1.7
#     institution:             US National Weather Service - NCEP
#     history:                 2025-09-05T17:33 GRIB to CDM+CF via cfgrib-0.9.1...
